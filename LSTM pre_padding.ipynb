# %%
from tensorflow.keras.datasets import imdb
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Embedding
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.models import load_model

# %%
vocab_size=10000
(x_train, y_train),(x_test, y_test) = imdb.load_data(num_words = vocab_size)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/imdb.npz
# 17465344/17464789 [==============================] - 0s 0us/step
# <string>:6: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/datasets/imdb.py:155: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   x_train, y_train = np.array(xs[:idx]), np.array(labels[:idx])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/datasets/imdb.py:156: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   x_test, y_test = np.array(xs[idx:]), np.array(labels[idx:])

# %%
max_len=500
x_train = pad_sequences(x_train, maxlen=max_len, padding='pre')
x_test = pad_sequences(x_test, maxlen=max_len, padding='pre')

# %%
x_train
# Out:
# array([[   0,    0,    0, ...,   19,  178,   32],
#        [   0,    0,    0, ...,   16,  145,   95],
#        [   0,    0,    0, ...,    7,  129,  113],
#        ...,
#        [   0,    0,    0, ...,    4, 3586,    2],
#        [   0,    0,    0, ...,   12,    9,   23],
#        [   0,    0,    0, ...,  204,  131,    9]], dtype=int32)

# %%
x_test
# Out:
# array([[   0,    0,    0, ...,   14,    6,  717],
#        [   0,    0,    0, ...,  125,    4, 3077],
#        [  33,    6,   58, ...,    9,   57,  975],
#        ...,
#        [   0,    0,    0, ...,   21,  846, 5518],
#        [   0,    0,    0, ..., 2302,    7,  470],
#        [   0,    0,    0, ...,   34, 2005, 2643]], dtype=int32)

# %%
model = Sequential()
model.add(Embedding(vocab_size,100))
model.add(LSTM(128))
model.add(Dense(1, activation = 'sigmoid'))

# %%
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=4)
mc = ModelCheckpoint('LSTM_model.h5', monitor='val_acc', mode='max', verbose=1, save_best_only=True)

# %%
model.compile(optimizer='rmsprop', loss='binary_crossentropy', metrics=['acc'])
history = model.fit(x_train, y_train, epochs=10, callbacks=[es, mc], batch_size=60, validation_split=0.2)
# Out:
# Epoch 1/10
# 334/334 [==============================] - 23s 44ms/step - loss: 0.4686 - acc: 0.7815 - val_loss: 0.3478 - val_acc: 0.8612
#
# Epoch 00001: val_acc improved from -inf to 0.86120, saving model to LSTM_model.h5
# Epoch 2/10
# 334/334 [==============================] - 14s 42ms/step - loss: 0.3116 - acc: 0.8782 - val_loss: 0.3779 - val_acc: 0.8316
#
# Epoch 00002: val_acc did not improve from 0.86120
# Epoch 3/10
# 334/334 [==============================] - 14s 42ms/step - loss: 0.2444 - acc: 0.9061 - val_loss: 0.5833 - val_acc: 0.7722
#
# Epoch 00003: val_acc did not improve from 0.86120
# Epoch 4/10
# 334/334 [==============================] - 14s 42ms/step - loss: 0.2194 - acc: 0.9208 - val_loss: 0.2896 - val_acc: 0.8814
#
# Epoch 00004: val_acc improved from 0.86120 to 0.88140, saving model to LSTM_model.h5
# Epoch 5/10
# 334/334 [==============================] - 15s 44ms/step - loss: 0.1813 - acc: 0.9339 - val_loss: 0.3100 - val_acc: 0.8730
#
# Epoch 00005: val_acc did not improve from 0.88140
# Epoch 6/10
# 334/334 [==============================] - 14s 43ms/step - loss: 0.1577 - acc: 0.9439 - val_loss: 0.3850 - val_acc: 0.8518
#
# Epoch 00006: val_acc did not improve from 0.88140
# Epoch 7/10
# 334/334 [==============================] - 14s 42ms/step - loss: 0.1356 - acc: 0.9522 - val_loss: 0.4338 - val_acc: 0.8598
#
# Epoch 00007: val_acc did not improve from 0.88140
# Epoch 8/10
# 334/334 [==============================] - 14s 41ms/step - loss: 0.1184 - acc: 0.9586 - val_loss: 0.3172 - val_acc: 0.8794
#
# Epoch 00008: val_acc did not improve from 0.88140
# Epoch 00008: early stopping

# %%
loaded_model = load_model('LSTM_model.h5')
print("\n 테스트 정확도: %.4f" % (loaded_model.evaluate(x_test, y_test)[1]))
# Out:
# 782/782 [==============================] - 11s 13ms/step - loss: 0.3127 - acc: 0.8756
#
#  테스트 정확도: 0.8756
