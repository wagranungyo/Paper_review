# %%
from tensorflow.keras.datasets import imdb
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Embedding
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.models import load_model

# %%
vocab_size=10000
(x_train, y_train),(x_test, y_test) = imdb.load_data(num_words = vocab_size)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/imdb.npz
# 17465344/17464789 [==============================] - 0s 0us/step
# <string>:6: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/datasets/imdb.py:155: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   x_train, y_train = np.array(xs[:idx]), np.array(labels[:idx])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/datasets/imdb.py:156: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   x_test, y_test = np.array(xs[idx:]), np.array(labels[idx:])

# %%
max_len=500
x_train = pad_sequences(x_train, maxlen=max_len, padding='post')
x_test = pad_sequences(x_test, maxlen=max_len, padding='post')

# %%
x_train
# Out:
# array([[   1,   14,   22, ...,    0,    0,    0],
#        [   1,  194, 1153, ...,    0,    0,    0],
#        [   1,   14,   47, ...,    0,    0,    0],
#        ...,
#        [   1,   11,    6, ...,    0,    0,    0],
#        [   1, 1446, 7079, ...,    0,    0,    0],
#        [   1,   17,    6, ...,    0,    0,    0]], dtype=int32)

# %%
x_test
# Out:
# array([[   1,  591,  202, ...,    0,    0,    0],
#        [   1,   14,   22, ...,    0,    0,    0],
#        [  33,    6,   58, ...,    9,   57,  975],
#        ...,
#        [   1,   13, 1408, ...,    0,    0,    0],
#        [   1,   11,  119, ...,    0,    0,    0],
#        [   1,    6,   52, ...,    0,    0,    0]], dtype=int32)

# %%
model = Sequential()
model.add(Embedding(vocab_size,100))
model.add(LSTM(128))
model.add(Dense(1, activation = 'sigmoid'))

# %%
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=4)
mc = ModelCheckpoint('LSTM_model.h5', monitor='val_acc', mode='max', verbose=1, save_best_only=True)

# %%
model.compile(optimizer='rmsprop', loss='binary_crossentropy', metrics=['acc'])
history = model.fit(x_train, y_train, epochs=10, callbacks=[es, mc], batch_size=60, validation_split=0.2)
# Out:
# Epoch 1/10
# 334/334 [==============================] - 43s 107ms/step - loss: 0.6952 - acc: 0.5052 - val_loss: 0.6920 - val_acc: 0.5066
#
# Epoch 00001: val_acc improved from -inf to 0.50660, saving model to LSTM_model.h5
# Epoch 2/10
# 334/334 [==============================] - 35s 104ms/step - loss: 0.6868 - acc: 0.5194 - val_loss: 0.6880 - val_acc: 0.5188
#
# Epoch 00002: val_acc improved from 0.50660 to 0.51880, saving model to LSTM_model.h5
# Epoch 3/10
# 334/334 [==============================] - 35s 104ms/step - loss: 0.6760 - acc: 0.5314 - val_loss: 0.6848 - val_acc: 0.5218
#
# Epoch 00003: val_acc improved from 0.51880 to 0.52180, saving model to LSTM_model.h5
# Epoch 4/10
# 334/334 [==============================] - 35s 104ms/step - loss: 0.6620 - acc: 0.5350 - val_loss: 0.8115 - val_acc: 0.5040
#
# Epoch 00004: val_acc did not improve from 0.52180
# Epoch 5/10
# 334/334 [==============================] - 35s 104ms/step - loss: 0.6523 - acc: 0.5426 - val_loss: 0.6800 - val_acc: 0.5304
#
# Epoch 00005: val_acc improved from 0.52180 to 0.53040, saving model to LSTM_model.h5
# Epoch 6/10
# 334/334 [==============================] - 34s 103ms/step - loss: 0.6069 - acc: 0.6337 - val_loss: 0.5587 - val_acc: 0.7672
#
# Epoch 00006: val_acc improved from 0.53040 to 0.76720, saving model to LSTM_model.h5
# Epoch 7/10
# 334/334 [==============================] - 35s 103ms/step - loss: 0.5618 - acc: 0.6996 - val_loss: 0.5350 - val_acc: 0.7726
#
# Epoch 00007: val_acc improved from 0.76720 to 0.77260, saving model to LSTM_model.h5
# Epoch 8/10
# 334/334 [==============================] - 35s 103ms/step - loss: 0.5064 - acc: 0.7821 - val_loss: 0.7001 - val_acc: 0.5080
#
# Epoch 00008: val_acc did not improve from 0.77260
# Epoch 9/10
# 334/334 [==============================] - 34s 103ms/step - loss: 0.6095 - acc: 0.6481 - val_loss: 0.7350 - val_acc: 0.5966
#
# Epoch 00009: val_acc did not improve from 0.77260
# Epoch 10/10
# 334/334 [==============================] - 35s 103ms/step - loss: 0.5430 - acc: 0.7272 - val_loss: 0.7286 - val_acc: 0.5102
#
# Epoch 00010: val_acc did not improve from 0.77260

# %%
loaded_model = load_model('LSTM_model.h5')
print("\n 테스트 정확도: %.4f" % (loaded_model.evaluate(x_test, y_test)[1]))
# Out:
# 782/782 [==============================] - 30s 38ms/step - loss: 0.5342 - acc: 0.7762
#
#  테스트 정확도: 0.7762
